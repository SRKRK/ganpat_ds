# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_excel('testIR01.xlsx')

# %%
df
# Out:
#      survey_number    medical_profile  \
# 0      P2100840101     Oncohematology
# 1      P2100840102  Internal Medicine
# 2      P2101130101        Dermatology
# 3      P2101130102         Pharmacist
# 4      P2101130103         Pharmacist
# ...            ...                ...
# 2256   P2302670102            Surgeon
# 2257   P2302670201        Dermatology
# 2258   P2302670202            Surgeon
# 2259   P2302670301        Dermatology
# 2260   P2302670302            Surgeon
#
#                                          Secondary_Spec Has_Secondary_Spec  \
# 0                    Hematology,Oncology,Oncohematology                Yes
# 1                                     Internal Medicine                 No
# 2                                           Dermatology                 No
# 3                    Medical Director,Pharmacy Director                Yes
# 4     Pharmacist,Community Pharmacist,Hospital Pharm...                Yes
# ...                                                 ...                ...
# 2256                 Plastic and reconstructive surgery                Yes
# 2257                                        Dermatology                 No
# 2258                 Plastic and reconstructive surgery                Yes
# 2259                                        Dermatology                 No
# 2260                 Plastic and reconstructive surgery                Yes
#
#       Country  incentive_offered incentives_currency_type  LOI  \
# 0         USA                 60                      USD   30
# 1         USA                 60                      USD   30
# 2         USA                 55                      USD   25
# 3         USA                 50                      USD   25
# 4         USA                 50                      USD   25
# ...       ...                ...                      ...  ...
# 2256  GERMANY                 55                      EUR   15
# 2257    SPAIN                 30                      EUR   15
# 2258    SPAIN                 40                      EUR   15
# 2259    ITALY                 30                      EUR   15
# 2260    ITALY                 40                      EUR   15
#
#       firstParticipation   lastParticipation  InhouseComplete  InhouseTQ  \
# 0    2021-09-14 06:26:47 2021-09-30 14:17:35               47         12
# 1    2021-09-20 13:20:44 2021-10-12 19:53:55                7          9
# 2    2021-04-12 12:22:02 2021-04-22 15:18:43               36          8
# 3    2021-04-13 16:06:29 2021-04-19 21:12:56                2          2
# 4    2021-04-18 12:46:54 2021-04-29 22:37:24                4          6
# ...                  ...                 ...              ...        ...
# 2256 2023-07-26 02:17:58 2023-07-27 03:44:56                0          4
# 2257 2023-07-25 14:57:49 2023-07-27 12:01:28                4          8
# 2258 2023-07-25 15:03:22 2023-07-26 03:00:14                0          2
# 2259 2023-07-25 15:00:08 2023-07-29 03:36:21                1          5
# 2260 2023-07-25 17:47:05 2023-07-25 17:47:05                0          1
#
#       Incidence Rate %  timeline_days
# 0            79.661017             16
# 1            43.750000             22
# 2            81.818182             10
# 3            50.000000              6
# 4            40.000000             11
# ...                ...            ...
# 2256          0.000000              1
# 2257         33.333333              1
# 2258          0.000000              0
# 2259         16.666667              3
# 2260          0.000000              0
#
# [2261 rows x 14 columns]

# %%
df1 = df.drop('Secondary_Spec',axis=1)

# %%
df1
# Out:
#      survey_number    medical_profile Has_Secondary_Spec  Country  \
# 0      P2100840101     Oncohematology                Yes      USA
# 1      P2100840102  Internal Medicine                 No      USA
# 2      P2101130101        Dermatology                 No      USA
# 3      P2101130102         Pharmacist                Yes      USA
# 4      P2101130103         Pharmacist                Yes      USA
# ...            ...                ...                ...      ...
# 2256   P2302670102            Surgeon                Yes  GERMANY
# 2257   P2302670201        Dermatology                 No    SPAIN
# 2258   P2302670202            Surgeon                Yes    SPAIN
# 2259   P2302670301        Dermatology                 No    ITALY
# 2260   P2302670302            Surgeon                Yes    ITALY
#
#       incentive_offered incentives_currency_type  LOI  firstParticipation  \
# 0                    60                      USD   30 2021-09-14 06:26:47
# 1                    60                      USD   30 2021-09-20 13:20:44
# 2                    55                      USD   25 2021-04-12 12:22:02
# 3                    50                      USD   25 2021-04-13 16:06:29
# 4                    50                      USD   25 2021-04-18 12:46:54
# ...                 ...                      ...  ...                 ...
# 2256                 55                      EUR   15 2023-07-26 02:17:58
# 2257                 30                      EUR   15 2023-07-25 14:57:49
# 2258                 40                      EUR   15 2023-07-25 15:03:22
# 2259                 30                      EUR   15 2023-07-25 15:00:08
# 2260                 40                      EUR   15 2023-07-25 17:47:05
#
#        lastParticipation  InhouseComplete  InhouseTQ  Incidence Rate %  \
# 0    2021-09-30 14:17:35               47         12         79.661017
# 1    2021-10-12 19:53:55                7          9         43.750000
# 2    2021-04-22 15:18:43               36          8         81.818182
# 3    2021-04-19 21:12:56                2          2         50.000000
# 4    2021-04-29 22:37:24                4          6         40.000000
# ...                  ...              ...        ...               ...
# 2256 2023-07-27 03:44:56                0          4          0.000000
# 2257 2023-07-27 12:01:28                4          8         33.333333
# 2258 2023-07-26 03:00:14                0          2          0.000000
# 2259 2023-07-29 03:36:21                1          5         16.666667
# 2260 2023-07-25 17:47:05                0          1          0.000000
#
#       timeline_days
# 0                16
# 1                22
# 2                10
# 3                 6
# 4                11
# ...             ...
# 2256              1
# 2257              1
# 2258              0
# 2259              3
# 2260              0
#
# [2261 rows x 13 columns]

# %%
df1.isna().sum()
# Out:
# survey_number               0
# medical_profile             0
# Has_Secondary_Spec          0
# Country                     0
# incentive_offered           0
# incentives_currency_type    0
# LOI                         0
# firstParticipation          0
# lastParticipation           0
# InhouseComplete             0
# InhouseTQ                   0
# Incidence Rate %            0
# timeline_days               0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.describe().T
# Out:
#                     count        mean         std  min        25%        50%  \
# incentive_offered  2261.0  108.024326  306.066781  0.0  30.000000  50.000000
# LOI                2261.0   23.453339   12.208193  5.0  15.000000  20.000000
# InhouseComplete    2261.0   10.567448   16.665674  0.0   2.000000   6.000000
# InhouseTQ          2261.0   12.552410   19.927468  0.0   2.000000   6.000000
# Incidence Rate %   2261.0   46.825671   30.357796  0.0  23.076923  46.666667
# timeline_days      2261.0   17.196373   19.280358  0.0   4.000000  12.000000
#
#                          75%     max
# incentive_offered  85.000000  4000.0
# LOI                30.000000    60.0
# InhouseComplete    13.000000   483.0
# InhouseTQ          15.000000   197.0
# Incidence Rate %   69.230769   100.0
# timeline_days      22.000000   237.0

# %%
df1.tail(10)
# Out:
#      survey_number              medical_profile Has_Secondary_Spec  \
# 2251   P2302600101                    Neurology                Yes
# 2252   P2302600201                    Neurology                Yes
# 2253   P2302630101                     Oncology                Yes
# 2254   P2302660101  Non Healthcare Professional                Yes
# 2255   P2302670101                  Dermatology                 No
# 2256   P2302670102                      Surgeon                Yes
# 2257   P2302670201                  Dermatology                 No
# 2258   P2302670202                      Surgeon                Yes
# 2259   P2302670301                  Dermatology                 No
# 2260   P2302670302                      Surgeon                Yes
#
#              Country  incentive_offered incentives_currency_type  LOI  \
# 2251             USA                100                      USD   40
# 2252  UNITED KINGDOM                100                      GBP   40
# 2253           INDIA               3500                      INR   20
# 2254             USA                 20                      USD   10
# 2255         GERMANY                 40                      EUR   15
# 2256         GERMANY                 55                      EUR   15
# 2257           SPAIN                 30                      EUR   15
# 2258           SPAIN                 40                      EUR   15
# 2259           ITALY                 30                      EUR   15
# 2260           ITALY                 40                      EUR   15
#
#       firstParticipation   lastParticipation  InhouseComplete  InhouseTQ  \
# 2251 2023-07-25 10:36:36 2023-07-28 20:56:36               17         28
# 2252 2023-07-27 09:50:16 2023-07-28 05:46:41                2          2
# 2253 2023-07-19 10:52:37 2023-07-26 10:08:56                4          8
# 2254 2023-07-24 09:08:35 2023-07-28 23:44:26               12        155
# 2255 2023-07-26 01:46:45 2023-07-28 06:51:33                1         15
# 2256 2023-07-26 02:17:58 2023-07-27 03:44:56                0          4
# 2257 2023-07-25 14:57:49 2023-07-27 12:01:28                4          8
# 2258 2023-07-25 15:03:22 2023-07-26 03:00:14                0          2
# 2259 2023-07-25 15:00:08 2023-07-29 03:36:21                1          5
# 2260 2023-07-25 17:47:05 2023-07-25 17:47:05                0          1
#
#       Incidence Rate %  timeline_days
# 2251         37.777778              3
# 2252         50.000000              0
# 2253         33.333333              6
# 2254          7.185629              4
# 2255          6.250000              2
# 2256          0.000000              1
# 2257         33.333333              1
# 2258          0.000000              0
# 2259         16.666667              3
# 2260          0.000000              0

# %%
#pip install forex-python

# %%
#from forex_python.converter import CurrencyRates

# %% [markdown]
# Function to convert incentive amount to USD
# def convert_to_usd(row):
#     currency = row["incentives_currency_type"]
#     amount = row["incentive_offered"]
#     if currency == "USD":
#         return amount
#     else:
#         c = CurrencyRates()
#         usd_amount = c.convert(currency, "USD", amount)
#         return usd_amount

# %%
# Apply the function to create a new column "Incentive_in_USD"
#df["Incentive_in_USD"] = df.apply(convert_to_usd, axis=1)

# %%
df.head()
# Out:
#   survey_number    medical_profile  \
# 0   P2100840101     Oncohematology
# 1   P2100840102  Internal Medicine
# 2   P2101130101        Dermatology
# 3   P2101130102         Pharmacist
# 4   P2101130103         Pharmacist
#
#                                       Secondary_Spec Has_Secondary_Spec  \
# 0                 Hematology,Oncology,Oncohematology                Yes
# 1                                  Internal Medicine                 No
# 2                                        Dermatology                 No
# 3                 Medical Director,Pharmacy Director                Yes
# 4  Pharmacist,Community Pharmacist,Hospital Pharm...                Yes
#
#   Country  incentive_offered incentives_currency_type  LOI  \
# 0     USA                 60                      USD   30
# 1     USA                 60                      USD   30
# 2     USA                 55                      USD   25
# 3     USA                 50                      USD   25
# 4     USA                 50                      USD   25
#
#    firstParticipation   lastParticipation  InhouseComplete  InhouseTQ  \
# 0 2021-09-14 06:26:47 2021-09-30 14:17:35               47         12
# 1 2021-09-20 13:20:44 2021-10-12 19:53:55                7          9
# 2 2021-04-12 12:22:02 2021-04-22 15:18:43               36          8
# 3 2021-04-13 16:06:29 2021-04-19 21:12:56                2          2
# 4 2021-04-18 12:46:54 2021-04-29 22:37:24                4          6
#
#    Incidence Rate %  timeline_days  Incentive_in_USD
# 0         79.661017             16              60.0
# 1         43.750000             22              60.0
# 2         81.818182             10              55.0
# 3         50.000000              6              50.0
# 4         40.000000             11              50.0

# %%
df1 = df.copy()

# %%
df1.drop(['survey_number','Secondary_Spec','incentive_offered','incentives_currency_type'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#      medical_profile Has_Secondary_Spec Country  LOI  firstParticipation  \
# 0     Oncohematology                Yes     USA   30 2021-09-14 06:26:47
# 1  Internal Medicine                 No     USA   30 2021-09-20 13:20:44
# 2        Dermatology                 No     USA   25 2021-04-12 12:22:02
# 3         Pharmacist                Yes     USA   25 2021-04-13 16:06:29
# 4         Pharmacist                Yes     USA   25 2021-04-18 12:46:54
#
#     lastParticipation  InhouseComplete  InhouseTQ  Incidence Rate %  \
# 0 2021-09-30 14:17:35               47         12         79.661017
# 1 2021-10-12 19:53:55                7          9         43.750000
# 2 2021-04-22 15:18:43               36          8         81.818182
# 3 2021-04-19 21:12:56                2          2         50.000000
# 4 2021-04-29 22:37:24                4          6         40.000000
#
#    timeline_days  Incentive_in_USD
# 0             16              60.0
# 1             22              60.0
# 2             10              55.0
# 3              6              50.0
# 4             11              50.0

# %%
df1.shape
# Out:
# (2261, 11)

# %%
df1.shape
# Out:
# (2261, 11)

# %%
df1 = df1.sort_values(by='firstParticipation')

# %%
df1.drop(['firstParticipation','lastParticipation'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#        medical_profile Has_Secondary_Spec  Country  LOI  InhouseComplete  \
# 14         Dermatology                 No      USA   20                2
# 15            Oncology                 No      USA   25               14
# 17  Mix Specialty type                 No      USA   30                0
# 2          Dermatology                 No      USA   25               36
# 16         Dermatology                 No  GERMANY   15                6
#
#     InhouseTQ  Incidence Rate %  timeline_days  Incentive_in_USD
# 14         15         11.764706             14             45.00
# 15          4         77.777778             13             60.00
# 17          2          0.000000              9             80.00
# 2           8         81.818182             10             55.00
# 16         38         13.636364             38             54.85

# %%
df1.rename(columns={'Incidence Rate %': 'IR_Perct'}, inplace=True)

# %%
df1.head()
# Out:
#        medical_profile Has_Secondary_Spec  Country  LOI  InhouseComplete  \
# 14         Dermatology                 No      USA   20                2
# 15            Oncology                 No      USA   25               14
# 17  Mix Specialty type                 No      USA   30                0
# 2          Dermatology                 No      USA   25               36
# 16         Dermatology                 No  GERMANY   15                6
#
#     InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD
# 14         15  11.764706             14             45.00
# 15          4  77.777778             13             60.00
# 17          2   0.000000              9             80.00
# 2           8  81.818182             10             55.00
# 16         38  13.636364             38             54.85

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2261 entries, 14 to 2217
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   medical_profile     2261 non-null   object
#  1   Has_Secondary_Spec  2261 non-null   object
#  2   Country             2261 non-null   object
#  3   LOI                 2261 non-null   int64
#  4   InhouseComplete     2261 non-null   int64
#  5   InhouseTQ           2261 non-null   int64
#  6   IR_Perct            2261 non-null   float64
#  7   timeline_days       2261 non-null   int64
#  8   Incentive_in_USD    2261 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 176.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(data=df1);

# %%
corr = df1.corr()

# %% [markdown]
# corr

# %%
corr
# Out:
#                        LOI  InhouseComplete  InhouseTQ  IR_Perct  \
# LOI               1.000000         0.020592   0.039497 -0.044248
# InhouseComplete   0.020592         1.000000   0.360026  0.292899
# InhouseTQ         0.039497         0.360026   1.000000 -0.287719
# IR_Perct         -0.044248         0.292899  -0.287719  1.000000
# timeline_days     0.176191         0.193455   0.163372  0.061944
# Incentive_in_USD  0.776573        -0.027376  -0.041583  0.009056
#
#                   timeline_days  Incentive_in_USD
# LOI                    0.176191          0.776573
# InhouseComplete        0.193455         -0.027376
# InhouseTQ              0.163372         -0.041583
# IR_Perct               0.061944          0.009056
# timeline_days          1.000000          0.238739
# Incentive_in_USD       0.238739          1.000000

# %%
sns.heatmap(corr, annot = True);

# %%
df1.columns
# Out:
# Index(['medical_profile', 'Has_Secondary_Spec', 'Country', 'LOI',
#        'InhouseComplete', 'InhouseTQ', 'IR_Perct', 'timeline_days',
#        'Incentive_in_USD'],
#       dtype='object')

# %%
sns.barplot(data= df1, y='InhouseComplete',x='Has_Secondary_Spec');

# %%
sns.histplot(data=df1, x='InhouseComplete');

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 9,6

# %%
df1.columns
# Out:
# Index(['medical_profile', 'Has_Secondary_Spec', 'Country', 'LOI',
#        'InhouseComplete', 'InhouseTQ', 'IR_Perct', 'timeline_days',
#        'Incentive_in_USD'],
#       dtype='object')

# %%
sns.countplot(data=df1,x='Country');

# %%
df1.head(1)
# Out:
#    medical_profile Has_Secondary_Spec Country  LOI  InhouseComplete  \
# 14     Dermatology                 No     USA   20                2
#
#     InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD
# 14         15  11.764706             14              45.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the continuous features
features = ['LOI', 'InhouseComplete', 'InhouseTQ', 'IR_Perct', 'timeline_days', 'Incentive_in_USD']

# Create subplots for each feature
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(10, 12))

# Iterate over the features and plot their distributions
for i, feature in enumerate(features):
    row = i // 2  # Calculate the row index
    col = i % 2  # Calculate the column index
    
    # Plot the distribution of the feature
    sns.histplot(data=df1, x=feature, kde=False, bins=30, color='blue', ax=axes[row, col])
    
    # Set the labels and title for the subplot
    axes[row, col].set_xlabel(feature, fontsize=12)
    axes[row, col].set_ylabel('Frequency', fontsize=12)
    axes[row, col].set_title('Distribution of ' + feature, fontsize=14)

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Univariate Analysis
plt.figure(figsize=(12, 9))

# Define the continuous features
features = ['LOI', 'InhouseComplete', 'InhouseTQ', 'IR_Perct', 'timeline_days', 'Incentive_in_USD']

for i in range(len(features)):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(y=df1[features[i]], data=df1)
    plt.title('Boxplot of {}'.format(features[i]))
    plt.tight_layout()

# %%
df1.head(1)
# Out:
#    medical_profile Has_Secondary_Spec Country  LOI  InhouseComplete  \
# 14     Dermatology                 No     USA   20                2
#
#     InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD
# 14         15  11.764706             14              45.0

# %%
import matplotlib.pyplot as plt

# Plotting the average insurance cost
plt.figure(figsize=(12, 6))
ax = df1.groupby('Country')['InhouseComplete'].mean().plot(marker='o')

# Customizing the plot
plt.ylabel('Average Internal completes')
plt.xticks(rotation=90)
plt.title('Average Internal completes by countries')

# Adjusting subplot parameters
plt.subplots_adjust(bottom=0.2, top=0.9)  # Adjust bottom and top spacing as per your preference

# Rotating x-axis labels further
for tick in ax.get_xticklabels():
    tick.set_rotation(90)

plt.show()

# %%
df1.groupby('medical_profile')['InhouseComplete'].mean().round(2).sort_values()
# Out:
# medical_profile
# Hepatology                                   0.00
# Radiation Oncology                           0.33
# Interventional Cardiology                    0.80
# Physician Assistant                          1.00
# Radiology                                    1.73
# Cardiovascular Disease                       2.00
# Reproductive Endocrinology - Infertility     2.00
# Sleep Medicine                               2.33
# MD - Orthopaedics                            2.50
# Non Healthcare Professional                  2.56
# Optometry (Not MD)                           2.60
# Nursing                                      3.49
# Critical Care Medicine                       3.62
# Electrophysiology                            3.67
# Geriatric Medicine                           3.67
# Infectious Disease Specialists               3.75
# Urology                                      3.78
# Infectious Disease                           3.80
# Pathology                                    4.27
# Surgeon                                      4.27
# Otolaryngology                               4.41
# Mix of Surgeons                              4.57
# Nephrology                                   4.89
# Mix Specialty                                5.09
# Pharmacist                                   5.19
# Internal Medicine                            5.59
# Anesthesiology                               6.40
# Pediatrics                                   6.66
# Obstetrics and Gynecology                    6.67
# Rheumatology                                 6.95
# Dermatology                                  7.77
# Endocrinology, Diabetes and Metabolism       8.52
# Ophthalmology                                8.78
# Mix Specialty type                           9.18
# Pulmonary Disease                            9.30
# Emergency Medicine                           9.50
# General Medicine                             9.67
# Allergy and Immunology                      10.00
# Gastroenterology                            10.01
# Neurology                                   10.13
# Veterinary Medicine                         12.00
# Cardiology                                  12.40
# Dentistry                                   13.53
# Hematology                                  13.72
# Oncohematology                              15.66
# Family Medicine                             16.30
# Oncology                                    17.81
# Psychiatry                                  19.33
# General Practice                            21.32
# Hospitalist                                 25.00
# Patients                                    60.00
# Name: InhouseComplete, dtype: float64

# %%
df1[df1['medical_profile'] == 'Patients']
# Out:
#     medical_profile Has_Secondary_Spec Country  LOI  InhouseComplete  \
# 193        Patients                 No     USA   30               60
#
#      InhouseTQ  IR_Perct  timeline_days  Incentive_in_USD
# 193          0     100.0              0               0.0

# %%
df1 = df1[df1['medical_profile'] != 'Patients']

# %%
df1.groupby(['medical_profile','Country'])['InhouseComplete'].mean().round(2).sort_values()
# Out:
# medical_profile                 Country
# Infectious Disease Specialists  FRANCE        0.00
# Interventional Cardiology       GERMANY       0.00
# Nursing                         AUSTRALIA     0.00
# Gastroenterology                INDIA         0.00
# Pathology                       INDIA         0.00
#                                              ...
# General Practice                CANADA       26.60
# Oncology                        SPAIN        27.85
# General Practice                SPAIN        28.38
# Dentistry                       USA          40.83
# General Practice                USA          44.95
# Name: InhouseComplete, Length: 297, dtype: float64

# %%
df1.skew()
# Out:
# C:\Users\Ganpat\AppData\Local\Temp\ipykernel_18880\149261804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.skew()
# LOI                  0.627659
# InhouseComplete     11.725141
# InhouseTQ            4.098646
# IR_Perct             0.102654
# timeline_days        2.812670
# Incentive_in_USD     1.970127
# dtype: float64

# %%
df1.head()
# Out:
#        medical_profile Has_Secondary_Spec  Country  LOI  InhouseComplete  \
# 14         Dermatology                 No      USA   20                2
# 15            Oncology                 No      USA   25               14
# 17  Mix Specialty type                 No      USA   30                0
# 2          Dermatology                 No      USA   25               36
# 16         Dermatology                 No  GERMANY   15                6
#
#     InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD
# 14         15  11.764706             14             45.00
# 15          4  77.777778             13             60.00
# 17          2   0.000000              9             80.00
# 2           8  81.818182             10             55.00
# 16         38  13.636364             38             54.85

# %%
#Let's check the number of outliers per column

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[5,95])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
outlier_cols=['InhouseComplete', 'InhouseTQ','timeline_days']

# %%
for column in outlier_cols:
    lr,ur=remove_outlier(df1[column])
    df1[column]=np.where(df1[column]>ur,ur,df1[column])
    df1[column]=np.where(df1[column]<lr,lr,df1[column])

# %%
df[outlier_cols].boxplot(vert=1)
plt.title("Outlier Check")
plt.show()

# %%
df1.columns
# Out:
# Index(['medical_profile', 'Has_Secondary_Spec', 'Country', 'LOI',
#        'InhouseComplete', 'InhouseTQ', 'IR_Perct', 'timeline_days',
#        'Incentive_in_USD'],
#       dtype='object')

# %%
df_dummy = pd.get_dummies(df1,drop_first=True,columns=['Has_Secondary_Spec','Country'])
df_dummy.head()
# Out:
#        medical_profile  LOI  InhouseComplete  InhouseTQ   IR_Perct  \
# 14         Dermatology   20              2.0       15.0  11.764706
# 15            Oncology   25             14.0        4.0  77.777778
# 17  Mix Specialty type   30              0.0        2.0   0.000000
# 2          Dermatology   25             36.0        8.0  81.818182
# 16         Dermatology   15              6.0       38.0  13.636364
#
#     timeline_days  Incentive_in_USD  Has_Secondary_Spec_Yes  Country_CANADA  \
# 14           14.0             45.00                       0               0
# 15           13.0             60.00                       0               0
# 17            9.0             80.00                       0               0
# 2            10.0             55.00                       0               0
# 16           38.0             54.85                       0               0
#
#     Country_FRANCE  Country_GERMANY  Country_INDIA  Country_ITALY  \
# 14               0                0              0              0
# 15               0                0              0              0
# 17               0                0              0              0
# 2                0                0              0              0
# 16               0                1              0              0
#
#     Country_SPAIN  Country_UNITED KINGDOM  Country_USA
# 14              0                       0            1
# 15              0                       0            1
# 17              0                       0            1
# 2               0                       0            1
# 16              0                       0            0

# %%
df_dummy.columns
# Out:
# Index(['medical_profile', 'LOI', 'InhouseComplete', 'InhouseTQ', 'IR_Perct',
#        'timeline_days', 'Incentive_in_USD', 'Has_Secondary_Spec_Yes',
#        'Country_CANADA', 'Country_FRANCE', 'Country_GERMANY', 'Country_INDIA',
#        'Country_ITALY', 'Country_SPAIN', 'Country_UNITED KINGDOM',
#        'Country_USA'],
#       dtype='object')

# %%
df_dummy.head()
# Out:
#        medical_profile  LOI  InhouseComplete  InhouseTQ   IR_Perct  \
# 14         Dermatology   20              2.0       15.0  11.764706
# 15            Oncology   25             14.0        4.0  77.777778
# 17  Mix Specialty type   30              0.0        2.0   0.000000
# 2          Dermatology   25             36.0        8.0  81.818182
# 16         Dermatology   15              6.0       38.0  13.636364
#
#     timeline_days  Incentive_in_USD  Has_Secondary_Spec_Yes  Country_CANADA  \
# 14           14.0             45.00                       0               0
# 15           13.0             60.00                       0               0
# 17            9.0             80.00                       0               0
# 2            10.0             55.00                       0               0
# 16           38.0             54.85                       0               0
#
#     Country_FRANCE  Country_GERMANY  Country_INDIA  Country_ITALY  \
# 14               0                0              0              0
# 15               0                0              0              0
# 17               0                0              0              0
# 2                0                0              0              0
# 16               0                1              0              0
#
#     Country_SPAIN  Country_UNITED KINGDOM  Country_USA
# 14              0                       0            1
# 15              0                       0            1
# 17              0                       0            1
# 2               0                       0            1
# 16              0                       0            0

# %% [markdown]
# ### Variable Transformation - Dependent variable

# %%
df_dummy['InhouseComplete'].skew()
# Out:
# 2.573569036794363

# %%
df_dummy.skew()
# Out:
# C:\Users\Ganpat\AppData\Local\Temp\ipykernel_18880\2337179923.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_dummy.skew()
# LOI                       0.627659
# InhouseComplete           2.573569
# InhouseTQ                 3.212657
# IR_Perct                  0.102654
# timeline_days             2.205726
# Incentive_in_USD          1.970127
# Has_Secondary_Spec_Yes   -0.350622
# Country_CANADA            3.820902
# Country_FRANCE            2.374263
# Country_GERMANY           1.832038
# Country_INDIA             5.550025
# Country_ITALY             3.768566
# Country_SPAIN             3.949982
# Country_UNITED KINGDOM    1.890676
# Country_USA               0.621242
# dtype: float64

# %%
sns.distplot(np.sqrt(df_dummy['InhouseComplete']))
# Out:
# <AxesSubplot:xlabel='InhouseComplete', ylabel='Density'>

# %%
from scipy import stats

# %%
transformed_data, lambda_value = stats.yeojohnson(df_dummy['InhouseComplete'])

# %%
sns.distplot(pd.DataFrame(transformed_data))
# Out:
# C:\Users\Ganpat\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
pd.DataFrame(transformed_data)
# Out:
#              0
# 0     1.114406
# 1     2.805369
# 2     0.000000
# 3     3.785321
# 4     1.995826
# ...        ...
# 2255  0.000000
# 2256  0.699412
# 2257  0.000000
# 2258  1.114406
# 2259  0.000000
#
# [2260 rows x 1 columns]

# %%
df_dummy['InhouseComplete_yeojohnson'] = transformed_data

# %%
df_dummy.head()
# Out:
#        medical_profile  LOI  InhouseComplete  InhouseTQ   IR_Perct  \
# 14         Dermatology   20              2.0       15.0  11.764706
# 15            Oncology   25             14.0        4.0  77.777778
# 17  Mix Specialty type   30              0.0        2.0   0.000000
# 2          Dermatology   25             36.0        8.0  81.818182
# 16         Dermatology   15              6.0       38.0  13.636364
#
#     timeline_days  Incentive_in_USD  Has_Secondary_Spec_Yes  Country_CANADA  \
# 14           14.0             45.00                       0               0
# 15           13.0             60.00                       0               0
# 17            9.0             80.00                       0               0
# 2            10.0             55.00                       0               0
# 16           38.0             54.85                       0               0
#
#     Country_FRANCE  Country_GERMANY  Country_INDIA  Country_ITALY  \
# 14               0                0              0              0
# 15               0                0              0              0
# 17               0                0              0              0
# 2                0                0              0              0
# 16               0                1              0              0
#
#     Country_SPAIN  Country_UNITED KINGDOM  Country_USA  \
# 14              0                       0            1
# 15              0                       0            1
# 17              0                       0            1
# 2               0                       0            1
# 16              0                       0            0
#
#     InhouseComplete_yeojohnson
# 14                    1.114406
# 15                    2.805369
# 17                    0.000000
# 2                     3.785321
# 16                    1.995826

# %%
df_dummy.drop('InhouseComplete',axis=1,inplace=True)

# %%
df_dummy['InhouseComplete_yeojohnson'] = df_dummy['InhouseComplete_yeojohnson'].replace('InhouseComplete_yeojohnson','InhouseComplete')

# %%
df_dummy.head()
# Out:
#        medical_profile  LOI  InhouseTQ   IR_Perct  timeline_days  \
# 14         Dermatology   20       15.0  11.764706           14.0
# 15            Oncology   25        4.0  77.777778           13.0
# 17  Mix Specialty type   30        2.0   0.000000            9.0
# 2          Dermatology   25        8.0  81.818182           10.0
# 16         Dermatology   15       38.0  13.636364           38.0
#
#     Incentive_in_USD  Has_Secondary_Spec_Yes  Country_CANADA  Country_FRANCE  \
# 14             45.00                       0               0               0
# 15             60.00                       0               0               0
# 17             80.00                       0               0               0
# 2              55.00                       0               0               0
# 16             54.85                       0               0               0
#
#     Country_GERMANY  Country_INDIA  Country_ITALY  Country_SPAIN  \
# 14                0              0              0              0
# 15                0              0              0              0
# 17                0              0              0              0
# 2                 0              0              0              0
# 16                1              0              0              0
#
#     Country_UNITED KINGDOM  Country_USA  InhouseComplete_yeojohnson
# 14                       0            1                    1.114406
# 15                       0            1                    2.805369
# 17                       0            1                    0.000000
# 2                        0            1                    3.785321
# 16                       0            0                    1.995826

# %%
df_dummy.rename(columns={'InhouseComplete_yeojohnson': 'InhouseComplete'}, inplace=True)

# %%
df_dummy.head()
# Out:
#        medical_profile  LOI  InhouseTQ   IR_Perct  timeline_days  \
# 14         Dermatology   20       15.0  11.764706           14.0
# 15            Oncology   25        4.0  77.777778           13.0
# 17  Mix Specialty type   30        2.0   0.000000            9.0
# 2          Dermatology   25        8.0  81.818182           10.0
# 16         Dermatology   15       38.0  13.636364           38.0
#
#     Incentive_in_USD  Has_Secondary_Spec_Yes  Country_CANADA  Country_FRANCE  \
# 14             45.00                       0               0               0
# 15             60.00                       0               0               0
# 17             80.00                       0               0               0
# 2              55.00                       0               0               0
# 16             54.85                       0               0               0
#
#     Country_GERMANY  Country_INDIA  Country_ITALY  Country_SPAIN  \
# 14                0              0              0              0
# 15                0              0              0              0
# 17                0              0              0              0
# 2                 0              0              0              0
# 16                1              0              0              0
#
#     Country_UNITED KINGDOM  Country_USA  InhouseComplete
# 14                       0            1         1.114406
# 15                       0            1         2.805369
# 17                       0            1         0.000000
# 2                        0            1         3.785321
# 16                       0            0         1.995826

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
train_df, test_df = train_test_split(df_dummy, test_size=0.3, random_state=42)

# %%
target_means = train_df.groupby('medical_profile')['InhouseComplete'].mean().to_dict()

# %%
train_df['medical_profile_encoded'] = train_df['medical_profile'].map(target_means)
test_df['medical_profile_encoded'] = test_df['medical_profile'].map(target_means)

# %%
test_df[test_df['medical_profile_encoded'] ==np.NaN]
# Out:
# Empty DataFrame
# Columns: [medical_profile, LOI, InhouseTQ, IR_Perct, timeline_days, Incentive_in_USD, Has_Secondary_Spec_Yes, Country_CANADA, Country_FRANCE, Country_GERMANY, Country_INDIA, Country_ITALY, Country_SPAIN, Country_UNITED KINGDOM, Country_USA, InhouseComplete, medical_profile_encoded]
# Index: []

# %%
test_df.dropna(inplace=True)

# %%
X_train = train_df.drop(['medical_profile', 'InhouseComplete'], axis=1)
y_train = train_df['InhouseComplete']

X_test = test_df.drop(['medical_profile', 'InhouseComplete'], axis=1)
y_test = test_df['InhouseComplete']

# %%
X_train.head()
# Out:
#       LOI  InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD  \
# 2184   10       19.0  32.142857            1.0         14.261000
# 351    25       47.0  42.682927           21.0         50.000000
# 122    20       14.0  61.111111           21.0         54.850000
# 2148   10        4.0  66.666667            2.0         21.940000
# 2035   30       10.0  52.380952            9.0         33.424556
#
#       Has_Secondary_Spec_Yes  Country_CANADA  Country_FRANCE  Country_GERMANY  \
# 2184                       1               0               0                0
# 351                        1               0               0                0
# 122                        1               0               0                1
# 2148                       1               0               0                0
# 2035                       1               0               0                0
#
#       Country_INDIA  Country_ITALY  Country_SPAIN  Country_UNITED KINGDOM  \
# 2184              0              0              1                       0
# 351               0              0              0                       0
# 122               0              0              0                       0
# 2148              0              1              0                       0
# 2035              1              0              0                       0
#
#       Country_USA  medical_profile_encoded
# 2184            0                 2.501999
# 351             1                 2.334704
# 122             0                 2.501999
# 2148            0                 2.219869
# 2035            0                 1.854281

# %%
X_train.head()
# Out:
#       LOI  InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD  \
# 2184   10       19.0  32.142857            1.0         14.261000
# 351    25       47.0  42.682927           21.0         50.000000
# 122    20       14.0  61.111111           21.0         54.850000
# 2148   10        4.0  66.666667            2.0         21.940000
# 2035   30       10.0  52.380952            9.0         33.424556
#
#       Has_Secondary_Spec_Yes  Country_CANADA  Country_FRANCE  Country_GERMANY  \
# 2184                       1               0               0                0
# 351                        1               0               0                0
# 122                        1               0               0                1
# 2148                       1               0               0                0
# 2035                       1               0               0                0
#
#       Country_INDIA  Country_ITALY  Country_SPAIN  Country_UNITED KINGDOM  \
# 2184              0              0              1                       0
# 351               0              0              0                       0
# 122               0              0              0                       0
# 2148              0              1              0                       0
# 2035              1              0              0                       0
#
#       Country_USA  medical_profile_encoded
# 2184            0                 2.501999
# 351             1                 2.334704
# 122             0                 2.501999
# 2148            0                 2.219869
# 2035            0                 1.854281

# %%
X_train_Num = X_train.iloc[:,:5]

# %%
X_train_Num
# Out:
#       LOI  InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD
# 2184   10       19.0  32.142857            1.0         14.261000
# 351    25       47.0  42.682927           21.0         50.000000
# 122    20       14.0  61.111111           21.0         54.850000
# 2148   10        4.0  66.666667            2.0         21.940000
# 2035   30       10.0  52.380952            9.0         33.424556
# ...   ...        ...        ...            ...               ...
# 1700   25       25.0  26.470588            9.0         24.308768
# 997    40        2.0  88.235294           15.0        204.413906
# 1170   15       16.0  42.857143           14.0         25.000000
# 1317   10        2.0  33.333333            0.0         28.522000
# 903    45       32.0  39.622642           24.0         85.000000
#
# [1582 rows x 5 columns]

# %%
# let's check the VIF of the predictors
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_series1 = pd.Series(
    [variance_inflation_factor(X_train_Num.values, i) for i in range(X_train_Num.shape[1])],
    index=X_train_Num.columns,
)
print("VIF values: \n\n{}\n".format(vif_series1))
# Out:
# VIF values:
#
# LOI                 9.538453
# InhouseTQ           1.485336
# IR_Perct            2.336748
# timeline_days       1.999448
# Incentive_in_USD    7.622698
# dtype: float64

# %%
X_train_Num.drop('LOI',axis=1,inplace=True)

# %%
X_train_Num
# Out:
#       InhouseTQ   IR_Perct  timeline_days  Incentive_in_USD
# 2184       19.0  32.142857            1.0         14.261000
# 351        47.0  42.682927           21.0         50.000000
# 122        14.0  61.111111           21.0         54.850000
# 2148        4.0  66.666667            2.0         21.940000
# 2035       10.0  52.380952            9.0         33.424556
# ...         ...        ...            ...               ...
# 1700       25.0  26.470588            9.0         24.308768
# 997         2.0  88.235294           15.0        204.413906
# 1170       16.0  42.857143           14.0         25.000000
# 1317        2.0  33.333333            0.0         28.522000
# 903        32.0  39.622642           24.0         85.000000
#
# [1582 rows x 4 columns]

# %%
# let's check the VIF of the predictors
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_series1 = pd.Series(
    [variance_inflation_factor(X_train_Num.values, i) for i in range(X_train_Num.shape[1])],
    index=X_train_Num.columns,
)
print("VIF values: \n\n{}\n".format(vif_series1))
# Out:
# VIF values:
#
# InhouseTQ           1.333016
# IR_Perct            2.034094
# timeline_days       1.997764
# Incentive_in_USD    2.336200
# dtype: float64

# %%
X_train.drop('LOI',axis=1,inplace=True)

# %%
X_test.drop('LOI',axis=1,inplace=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# To build linear regression_model
import statsmodels.api as sm

# To check model performance
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ### Linear Regression using statsmodels(OLS)

# %%
X_train_lr=sm.add_constant(X_train)# This adds the constant term beta0 to the Simple Linear Regression.
X_test_lr=sm.add_constant(X_test)

# %%
model = sm.OLS(y_train,X_train_lr).fit()
model

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        InhouseComplete   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     272.1
# Date:                Sun, 06 Aug 2023   Prob (F-statistic):               0.00
# Time:                        12:36:00   Log-Likelihood:                -1444.0
# No. Observations:                1582   AIC:                             2918.
# Df Residuals:                    1567   BIC:                             2999.
# Df Model:                          14
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -1.0532      0.150     -7.007      0.000      -1.348      -0.758
# InhouseTQ                   0.0255      0.001     25.293      0.000       0.024       0.028
# IR_Perct                    0.0224      0.001     39.501      0.000       0.021       0.023
# timeline_days               0.0068      0.001      8.002      0.000       0.005       0.008
# Incentive_in_USD           -0.0013      0.000     -3.557      0.000      -0.002      -0.001
# Has_Secondary_Spec_Yes      0.1305      0.032      4.063      0.000       0.068       0.194
# Country_CANADA              0.4109      0.149      2.753      0.006       0.118       0.704
# Country_FRANCE              0.0990      0.144      0.688      0.492      -0.183       0.381
# Country_GERMANY             0.4376      0.142      3.081      0.002       0.159       0.716
# Country_INDIA               0.2962      0.166      1.786      0.074      -0.029       0.621
# Country_ITALY               0.7315      0.153      4.790      0.000       0.432       1.031
# Country_SPAIN               0.8462      0.152      5.550      0.000       0.547       1.145
# Country_UNITED KINGDOM      0.3761      0.142      2.653      0.008       0.098       0.654
# Country_USA                 0.7652      0.140      5.457      0.000       0.490       1.040
# medical_profile_encoded     0.5101      0.032     15.977      0.000       0.447       0.573
# ==============================================================================
# Omnibus:                      235.282   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              432.314
# Skew:                          -0.927   Prob(JB):                     1.33e-94
# Kurtosis:                       4.768   Cond. No.                     2.49e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.49e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.api as sm

# Add a constant column to the X_train and X_test data
X_train_lr = sm.add_constant(X_train_lr)
X_test_lr = sm.add_constant(X_test_lr)

# Initialize a list to store the insignificant variables
insignificant_vars = []

# Create and fit the initial linear regression model
model = sm.OLS(y_train, X_train_lr)
results = model.fit()

# Iteratively drop insignificant variables
while True:
    # Get the p-values for all variables
    p_values = results.pvalues[1:]  # Exclude the constant term

    # Find the first variable with p-value > 0.05
    max_p_value = p_values.max()
    if max_p_value > 0.05:
        # Find the index of the variable with the highest p-value
        var_to_drop = p_values.idxmax()
        # Remove the variable from X_train and X_test
        X_train_lr.drop(var_to_drop, axis=1, inplace=True)
        X_test_lr.drop(var_to_drop, axis=1, inplace=True)
        # Add the dropped variable to the insignificant_vars list
        insignificant_vars.append(var_to_drop)
    else:
        break

    # Refit the model without the dropped variable
    model = sm.OLS(y_train, X_train_lr)
    results = model.fit()

# Print the final summary of the model
print(results.summary())

# Make predictions on the test set
y_pred = results.predict(X_test_lr)

# Print the insignificant variables
print("Dropped insignificant variables:", insignificant_vars)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        InhouseComplete   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     293.1
# Date:                Sun, 06 Aug 2023   Prob (F-statistic):               0.00
# Time:                        12:36:03   Log-Likelihood:                -1444.3
# No. Observations:                1582   AIC:                             2917.
# Df Residuals:                    1568   BIC:                             2992.
# Df Model:                          13
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.9630      0.073    -13.122      0.000      -1.107      -0.819
# InhouseTQ                   0.0255      0.001     25.308      0.000       0.024       0.028
# IR_Perct                    0.0224      0.001     39.582      0.000       0.021       0.024
# timeline_days               0.0068      0.001      8.008      0.000       0.005       0.009
# Incentive_in_USD           -0.0014      0.000     -3.683      0.000      -0.002      -0.001
# Has_Secondary_Spec_Yes      0.1304      0.032      4.059      0.000       0.067       0.193
# Country_CANADA              0.3229      0.077      4.199      0.000       0.172       0.474
# Country_GERMANY             0.3480      0.057      6.144      0.000       0.237       0.459
# Country_INDIA               0.2052      0.100      2.053      0.040       0.009       0.401
# Country_ITALY               0.6411      0.078      8.230      0.000       0.488       0.794
# Country_SPAIN               0.7555      0.077      9.858      0.000       0.605       0.906
# Country_UNITED KINGDOM      0.2866      0.056      5.095      0.000       0.176       0.397
# Country_USA                 0.6754      0.051     13.195      0.000       0.575       0.776
# medical_profile_encoded     0.5105      0.032     15.994      0.000       0.448       0.573
# ==============================================================================
# Omnibus:                      234.856   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              431.598
# Skew:                          -0.925   Prob(JB):                     1.90e-94
# Kurtosis:                       4.768   Cond. No.                         799.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Dropped insignificant variables: ['Country_FRANCE']

# %%
# Make predictions on the test set
y_pred_train = results.predict(X_train_lr)

# %%
# Calculate evaluation metrics
r2_score_value = r2_score(y_train, y_pred_train)
mae = mean_absolute_error(y_train, y_pred_train)
mse = mean_squared_error(y_train, y_pred_train)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_train - y_pred_train) / y_train)) * 100
mpe = np.mean((y_train - y_pred_train) / y_train) * 100

# Create a DataFrame to store the results
results_df_Linear_Train = pd.DataFrame({
    'Model': ['Linear Regression'],
    'R2 Score': [r2_score_value],
    'Mean Absolute Error': [mae],
    'Mean Squared Error': [mse],
    'Root Mean Squared Error': [rmse],
    'Mean Absolute Percentage Error': [mape],
    'Mean Percentage Error': [mpe]
})

# %%
round(results_df_Linear_Train,4)
# Out:
#                Model  R2 Score  Mean Absolute Error  Mean Squared Error  \
# 0  Linear Regression    0.7085               0.4603              0.3635
#
#    Root Mean Squared Error  Mean Absolute Percentage Error  \
# 0                   0.6029                             inf
#
#    Mean Percentage Error
# 0                    NaN

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
ss=StandardScaler() 
# we are scaling the data for ANN. Without scaling it will give very poor results. Computations becomes easier
x_train_scaled=ss.fit_transform(X_train)
x_test_scaled=ss.transform(X_test)

# %%
annr = MLPRegressor(hidden_layer_sizes=(500),random_state=123, max_iter=10000)#you are free to tweak the layer sizes
rfr = RandomForestRegressor(random_state=123)
dtr = tree.DecisionTreeRegressor(random_state=123)
regression_model = LinearRegression()

models=[regression_model,dtr,rfr,annr]

rmse_train=[]
rmse_test=[]
scores_train=[]
scores_test=[]

for i in models:  # we are scaling the data for ANN. Without scaling it will give very poor results. Computations becomes easier
    
    if (i != annr) :
        i.fit(X_train,y_train)
        scores_train.append(i.score(X_train, y_train))
        scores_test.append(i.score(X_test, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(X_train))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(X_test))))
 
    else :
        i.fit(x_train_scaled,y_train)
        scores_train.append(i.score(x_train_scaled, y_train))
        scores_test.append(i.score(x_test_scaled, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(x_train_scaled))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(x_test_scaled))))
        
print(pd.DataFrame({'Train RMSE': rmse_train,'Test RMSE': rmse_test,'Training Score':scores_train,'Test Score': scores_test},
            index=['Linear Regression','Decision Tree Regressor','Random Forest Regressor', 'ANN Regressor']))
# Out:
#                          Train RMSE  Test RMSE  Training Score  Test Score
# Linear Regression          0.602818   0.620681        0.708570    0.724194
# Decision Tree Regressor    0.012743   0.327582        0.999870    0.923174
# Random Forest Regressor    0.096281   0.275690        0.992566    0.945586
# ANN Regressor              0.217428   0.339573        0.962086    0.917447

# %%
param_grid = {
    'max_depth': [10,15,20,25,30],
    'min_samples_leaf': [3, 15,30],
    'min_samples_split': [15,30,35,40,50],
}

dtr=tree.DecisionTreeRegressor(random_state=123)

grid_search = GridSearchCV(estimator = dtr, param_grid = param_grid, cv = 3)


grid_search.fit(X_train,y_train)

print(grid_search.best_params_)
# Out:
# {'max_depth': 15, 'min_samples_leaf': 3, 'min_samples_split': 15}

# %%
param_grid = {
    'max_depth': [7,10],
    'max_features': [4, 6],
    'min_samples_leaf': [3, 15,30],
    'min_samples_split': [30, 50,100],
    'n_estimators': [300, 500]
}

rfr = RandomForestRegressor(random_state=123)

grid_search = GridSearchCV(estimator = rfr, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=123),
#              param_grid={'max_depth': [7, 10], 'max_features': [4, 6],
#                          'min_samples_leaf': [3, 15, 30],
#                          'min_samples_split': [30, 50, 100],
#                          'n_estimators': [300, 500]})

# %%
print(grid_search.best_params_)
# Out:
# {'max_depth': 10, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 30, 'n_estimators': 300}

# %%
#Grid search for ANN

# %%
param_grid = {
    'hidden_layer_sizes':[(500),(100,100)], 
    # keeping these simple because it would take too much time to run on low-end computers
    "activation": ["tanh", "relu"], 
    "solver": ["sgd", "adam"]}

annr = MLPRegressor(max_iter=10000, random_state=123)

grid_search = GridSearchCV(estimator = annr, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(x_train_scaled,y_train)
# Out:
# GridSearchCV(cv=3, estimator=MLPRegressor(max_iter=10000, random_state=123),
#              param_grid={'activation': ['tanh', 'relu'],
#                          'hidden_layer_sizes': [500, (100, 100)],
#                          'solver': ['sgd', 'adam']})

# %%
print(grid_search.best_params_)
# Out:
# {'activation': 'relu', 'hidden_layer_sizes': 500, 'solver': 'adam'}

# %%
annr = MLPRegressor(activation='tanh', hidden_layer_sizes=(500), 
                    solver='adam',random_state=123, 
                    max_iter=10000)
rfr = RandomForestRegressor(max_depth=10, max_features=6, 
                            min_samples_leaf= 3,
                            min_samples_split= 30, n_estimators= 300,
                            random_state=123)
dtr = tree.DecisionTreeRegressor(max_depth=15,min_samples_split=15,min_samples_leaf=3,random_state=123)
regression_model = LinearRegression()

models=[regression_model,dtr,rfr,annr]

rmse_train=[]
rmse_test=[]
scores_train=[]
scores_test=[]
mape_train=[]
mape_test=[]

for i in models:
    if (i != annr):
        i.fit(X_train,y_train)
        scores_train.append(i.score(X_train, y_train))
        scores_test.append(i.score(X_test, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(X_train))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(X_test))))
        
    else :
        i.fit(x_train_scaled,y_train)
        scores_train.append(i.score(x_train_scaled, y_train))
        scores_test.append(i.score(x_test_scaled, y_test))
        rmse_train.append(np.sqrt(mean_squared_error(y_train,i.predict(x_train_scaled))))
        rmse_test.append(np.sqrt(mean_squared_error(y_test,i.predict(x_test_scaled))))
        
        
print(pd.DataFrame({'Train RMSE': rmse_train,'Test RMSE': rmse_test,'Training Score':scores_train,'Test Score': scores_test},
            index=['Linear Regression','Decision Tree Regressor','Random Forest Regressor', 'ANN Regressor']))
# Out:
#                          Train RMSE  Test RMSE  Training Score  Test Score
# Linear Regression          0.602818   0.620681        0.708570    0.724194
# Decision Tree Regressor    0.208108   0.285965        0.965267    0.941455
# Random Forest Regressor    0.326557   0.398344        0.914477    0.886399
# ANN Regressor              0.299712   0.361322        0.927960    0.906534

# %%
import pickle

# %%
pickle.dump(dtr,open('dtr.pkl','wb'))

# %%
pickled_model =pickle.load(open('dtr.pkl','rb'))
